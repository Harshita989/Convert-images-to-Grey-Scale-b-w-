# %% [markdown]
# <a href="https://colab.research.google.com/github/Harshita989/Convert-images-to-Grey-Scale-b-w-/blob/main/Convert_images_to_grey_scale.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install google_images_search
# Out:
# Collecting google_images_search
#   Downloading Google_Images_Search-1.4.6-py2.py3-none-any.whl (12 kB)
# Collecting colorama~=0.4 (from google_images_search)
#   Downloading colorama-0.4.6-py2.py3-none-any.whl (25 kB)
# Collecting pyfiglet~=0.8 (from google_images_search)
#   Downloading pyfiglet-0.8.post1-py2.py3-none-any.whl (865 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 865.8/865.8 kB 5.1 MB/s eta 0:00:00
# Collecting termcolor~=1.1 (from google_images_search)
#   Downloading termcolor-1.1.0.tar.gz (3.9 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: click>=7.0<=8.1.* in /usr/local/lib/python3.10/dist-packages (from google_images_search) (8.1.7)
# Requirement already satisfied: six~=1.12 in /usr/local/lib/python3.10/dist-packages (from google_images_search) (1.16.0)
# Requirement already satisfied: requests~=2.21 in /usr/local/lib/python3.10/dist-packages (from google_images_search) (2.31.0)
# Requirement already satisfied: Pillow>=8.1.1 in /usr/local/lib/python3.10/dist-packages (from google_images_search) (9.4.0)
# Collecting python-resize-image~=1.1 (from google_images_search)
#   Downloading python_resize_image-1.1.20-py2.py3-none-any.whl (8.4 kB)
# Collecting google-api-python-client~=2.48.0 (from google_images_search)
#   Downloading google_api_python_client-2.48.0-py2.py3-none-any.whl (8.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.5/8.5 MB 14.3 MB/s eta 0:00:00
# Requirement already satisfied: httplib2<1dev,>=0.15.0 in /usr/local/lib/python3.10/dist-packages (from google-api-python-client~=2.48.0->google_images_search) (0.22.0)
# Requirement already satisfied: google-auth<3.0.0dev,>=1.16.0 in /usr/local/lib/python3.10/dist-packages (from google-api-python-client~=2.48.0->google_images_search) (2.27.0)
# Requirement already satisfied: google-auth-httplib2>=0.1.0 in /usr/local/lib/python3.10/dist-packages (from google-api-python-client~=2.48.0->google_images_search) (0.1.1)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5 in /usr/local/lib/python3.10/dist-packages (from google-api-python-client~=2.48.0->google_images_search) (2.11.1)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in /usr/local/lib/python3.10/dist-packages (from google-api-python-client~=2.48.0->google_images_search) (4.1.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests~=2.21->google_images_search) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests~=2.21->google_images_search) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests~=2.21->google_images_search) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests~=2.21->google_images_search) (2024.6.2)
# Requirement already satisfied: googleapis-common-protos<2.0.dev0,>=1.56.2 in /usr/local/lib/python3.10/dist-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-api-python-client~=2.48.0->google_images_search) (1.63.1)
# Requirement already satisfied: protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0.dev0,>=3.19.5 in /usr/local/lib/python3.10/dist-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-api-python-client~=2.48.0->google_images_search) (3.20.3)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3.0.0dev,>=1.16.0->google-api-python-client~=2.48.0->google_images_search) (5.3.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<3.0.0dev,>=1.16.0->google-api-python-client~=2.48.0->google_images_search) (0.4.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth<3.0.0dev,>=1.16.0->google-api-python-client~=2.48.0->google_images_search) (4.9)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in /usr/local/lib/python3.10/dist-packages (from httplib2<1dev,>=0.15.0->google-api-python-client~=2.48.0->google_images_search) (3.1.2)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.0dev,>=1.16.0->google-api-python-client~=2.48.0->google_images_search) (0.6.0)
# Building wheels for collected packages: termcolor
#   Building wheel for termcolor (setup.py) ... done
#   Created wheel for termcolor: filename=termcolor-1.1.0-py3-none-any.whl size=4832 sha256=01f1885d91fedbbce9108eb90f4de1eb3369c592b9c62c6642ca5f458155653d
#   Stored in directory: /root/.cache/pip/wheels/a1/49/46/1b13a65d8da11238af9616b00fdde6d45b0f95d9291bac8452
# Successfully built termcolor
# Installing collected packages: termcolor, pyfiglet, colorama, python-resize-image, google-api-python-client, google_images_search
#   Attempting uninstall: termcolor
#     Found existing installation: termcolor 2.4.0
#     Uninstalling termcolor-2.4.0:
#       Successfully uninstalled termcolor-2.4.0
#   Attempting uninstall: google-api-python-client
#     Found existing installation: google-api-python-client 2.84.0
#     Uninstalling google-api-python-client-2.84.0:
#       Successfully uninstalled google-api-python-client-2.84.0
# Successfully installed colorama-0.4.6 google-api-python-client-2.48.0 google_images_search-1.4.6 pyfiglet-0.8.post1 python-resize-image-1.1.20 termcolor-1.1.0

# %%
from google_images_search import GoogleImagesSearch
import zipfile
import os
# you can provide API key and CX using arguments,
# or you can set environment variables: GCS_DEVELOPER_KEY, GCS_CX
gis = GoogleImagesSearch('AIzaSyCGyqf36D5k3QghaZLhAqb1R2OUtRFraF8' , '0d386b282da5209ea' , validate_images=True)
def search(keyword, imageNumber):
    _search_params = {
        'q': keyword,
        'num': imageNumber,
        # 'safe': 'medium',
        # 'fileType': 'jpg',
        # 'imgType': 'photo',
        'imgSize': 'SMALL',
        # 'imgDominantColor': 'brown',
        # 'rights': 'cc_publicdomain'
    }

    #path_to_dir: where the downloaded images must be stored
    gis.search(search_params=_search_params, path_to_dir='./colouredimages/')

##calling search function to download 10 motorbike images
search('India',100)

# %%
#Now we will just pass the coloured image directory and then it will change to greyscale

import cv2
import os

# Set the directory path where the images are located
image_dir = "/content/colouredimages"

# Create a new directory to store the grayscale images
grayscale_dir = "/content/Greyscale"
os.makedirs(grayscale_dir, exist_ok=True)

# Loop through the first 100 image files in the directory
for i, filename in enumerate(os.listdir(image_dir)[:100], start=1):
    if filename.endswith(".jpg") or filename.endswith(".png"):
        # Load the image
        image_path = os.path.join(image_dir, filename)
        image = cv2.imread(image_path)

        # Convert the image to grayscale
        grayscale_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

        # Save the grayscale image with a new filename
        grayscale_filename = f"grayscale_{i}.jpg"
        grayscale_path = os.path.join(grayscale_dir, grayscale_filename)
        cv2.imwrite(grayscale_path, grayscale_image)

        print(f"Converted image {i}: {filename}")

print("Conversion complete.")
# Out:
# Converted image 1: India_78.40398E_20.74980N.jpg
# Converted image 2: image1170x530cropped.jpg
# Converted image 3: DFO4PA5KSZJQXBAUNSVF6STB2Q.jpg
# Converted image 4: india-pm-modi-russia-president-putin.jpg
# Converted image 5: image-1706297520.jpg
# Converted image 6: 02india-econ-01-mtkp-mediumSquareAt3X-v2.jpg
# Converted image 7: 6345345345-5.jpg
# Converted image 8: 00india-opposition-explainer-01-pgkm-videoSixteenByNine3000.jpg
# Converted image 9: shutterstock_2183275499-1920x1281.jpg
# Converted image 10: India-country-page.jpg
# Converted image 11: india-ganges-river_4x3.jpg
# Converted image 12: Sec-india-1243634976.jpg
# Converted image 13: India-2023_screen-shot.png
# Converted image 14: 65459369_605.jpg
# Converted image 15: GettyImages-1239738197.jpg
# Converted image 16: 2022-04-12T161224Z_832813658_RC2SLT921347_RTRMADP_3_RELIGION-RAMADAN-INDIA-e1682355606344-1024x616.jpg
# Converted image 17: maxresdefault.jpg
# Converted image 18: 230322124547-amritpal-singh-030323.jpg
# Converted image 19: map-india.png
# Converted image 20: India-map_2x1.jpg
# Converted image 21: ogb_115272_india_chhatiya_main_picture.jpg
# Converted image 22: _128387646_bbcmp_india.png
# Converted image 23: why-india-us-partner.jpg
# Converted image 24: Green-Hydrogen-DPL.jpg
# Converted image 25: India-states-compared-countries-MAIN-2.jpg
# Converted image 26: 230428-india-reproductive-rights-mjf-1558-750bc0.jpg
# Converted image 28: india-ganges-river.jpg
# Converted image 29: india-tajmahal_16x9.jpg
# Converted image 30: Flag-India.jpg
# Converted image 31: Article-Media-India.jpg
# Converted image 32: 3FnczamRyWU6MvRMEXWaGD-1200-80.jpg
# Converted image 33: india-mouLO.jpg
# Converted image 34: 06india-bharat-1-khcb-mediumSquareAt3X.jpg
# Converted image 35: ZK3AVJ2AAZPZDICSTTKATGHWMA.jpg
# Converted image 36: 01-india-economic-boom-feature-cnn.jpg
# Converted image 38: ERRK5WUB5VJYLHSZJDCE3IBOJQ.jpg
# Converted image 39: 107299219-Thumbnail_Digital_Originals_India_Multilateralism_V2_Clean.jpg
# Converted image 40: India-map_2x3.jpg
# Converted image 41: 31DC-INDIATRADE-01-phvj-articleLarge.jpg
# Converted image 42: 20231104_BLP907.jpg
# Converted image 43: India-7Rpy4sp7H-k-unsplash-chelsea-aaron.jpg
# Converted image 44: country_image_India.jpg
# Converted image 45: 231017-india-lgbt-mb-1050-cd5225.jpg
# Converted image 46: 2023-09-25T205650Z_1810559300_RC2WF3ASXGNO_RTRMADP_3_CANADA-INDIA-1024x701.jpg
# Converted image 47: _128075992_screenshot2022-12-20134517.png
# Converted image 48: _128186942_bbcm_india_country_profile_map_030123.jpg
# Converted image 49: AP20110546979418-1714359746.jpg
# Converted image 50: 2024-06-05-india-elections-index-videoSixteenByNine3000-v6.jpg
# Converted image 51: 800px-Flag_of_India.svg.png
# Converted image 52: GettyImages-928851490.jpg
# Converted image 53: 20231007_ASP004.jpg
# Converted image 54: INDIA_Bloc.png
# Converted image 55: India-Accelarator-Press-Release-1-1280x720.png
# Converted image 56: holywaters.jpg
# Converted image 57: indiacarouselimage1.jpg
# Converted image 58: 31india-econ-1-superJumbo-v2.jpg
# Converted image 59: PF_06.29.21_India-00-0.png
# Converted image 60: country-banner-india.jpg
# Converted image 61: 20240417-india-elex-hpv2.png
# Converted image 62: india-sub__0003_india-agra-taj-mahal-at-dawn.jpg
# Converted image 64: 240506-india-election-mb-1001-87f8c1.jpg
# Converted image 65: hq720.jpg
# Converted image 67: 20210415PHT02103_original.jpg
# Converted image 68: 01-india-travel.jpg
# Converted image 69: FT_23.01.18_IndiaPopulation_feature.jpg
# Converted image 70: GettyImages-1500645962.jpg
# Converted image 71: in-01.jpg
# Converted image 72: SMS5ZFHKMBJALKCF4FLDHDUACU.jpg
# Converted image 73: 2024-05-08T144247Z_523204445_RC2GK5A99QKD_RTRMADP_3_AIR-INDIA-EXPRESS-FLIGHTS-1715239632.jpg
# Converted image 74: 1200x675_cmsv2_3c5f007a-9345-5211-9b5d-a2d04af6c001-7880686.jpg
# Converted image 75: 960x0.jpg
# Converted image 76: 1660060831-safetravelinda_hero.jpg
# Converted image 79: article-hero-image-2067.jpg
# Converted image 80: 230117103106-01-india-new-year-crowd-123122-restricted.jpg
# Converted image 81: building-for-billions-indias-rise-to-becoming-the-most-populous-nation_1.jpg
# Converted image 82: 2023-08-22T113151Z_1475396292_RC2VS2AAQKKG_RTRMADP_3_INDIA-SPACE-1703615533.jpg
# Converted image 83: 914IqHav6IL._AC_UF1000,1000_QL80_.jpg
# Converted image 85: India-Urbanization-Challenge_An-Opportunity-Innovation_FeatureImage.png
# Converted image 86: ivankatrump:story.jpg
# Converted image 87: bdacbdf6-India-Protest.jpg
# Converted image 88: 1200px-Government_of_India_logo.svg.png
# Converted image 89: FULCPGZWABIALBM2WJSBKG7YWI.jpg
# Converted image 90: Taj_Mahal_New_Delhi_India.jpg
# Converted image 91: India-map.jpg
# Converted image 92: 02india-econ-01-mtkp-videoSixteenByNine3000.jpg
# Converted image 93: ETDCH8_IndiaMumbai_web.jpg
# Converted image 94: 1200px-Flag_of_India.svg.png
# Converted image 95: 240508-modi-india-vote-mb-0907-dbb2ce.jpg
# Converted image 96: republic-day-india-january26-gettyimages-56671040.jpg
# Converted image 97: LE2RI3XNP5PKXP3DECBXPFWTE4.jpg
# Converted image 98: 1673275741989.jpg
# Conversion complete.
